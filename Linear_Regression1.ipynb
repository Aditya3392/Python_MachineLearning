# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya3392/Python_MachineLearning/blob/main/Linear_Regression1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

df=pd.read_csv('/content/student_scores.csv')
print(df)

x=df['Hours'].values.reshape((-1,1))
y=df['Scores']

SLR=LinearRegression()
SLR.fit(x,y)

pred=SLR.predict(x)



plt.scatter(x,y,label="Known data")
plt.plot(x,pred,color="red",label="Regression Line")
plt.legend()
plt.show()
mse=mean_squared_error(y,pred)
print("intercept",SLR.intercept_)
print("mse:",mse)
print("Slope:",SLR.coef_)
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86
# intercept 2.48367340537321
# mse: 28.882730509245466
# Slope: [9.77580339]
